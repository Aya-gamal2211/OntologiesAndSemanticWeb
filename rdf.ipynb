# %%
import rdflib
from rdflib.graph import Graph,URIRef,RDF
from rdflib.namespace import DC, FOAF,Namespace

from rdflib.tools import rdf2dot
from rdflib.plugins.sparql import prepareQuery
import owlrl

# %%
# Load the ontology from a file
g = Graph()
g.parse("C:\\Users\\Shaima\\Desktop\\OntologiesAndSemanticWeb\\OntologiesPart.ttl", format="ttl")

# Define the URI for the Person class
PERSON = URIRef("http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person")

# List to store individuals of Person class
persons = []

# Iterate through all triples in the graph
for subj, pred, obj in g:
    # Check if the subject is a Person
    if pred == RDF.type and obj == PERSON:
        persons.append(subj)

# Print the individuals of Person class
for person in persons:
    print(person)

# %%
# Iterate through all triples in the graph
for subj, pred, obj in g:
    # print("Triple:", subj)  # Debugging statement
    # Check if the subject is a Person
    if pred == RDF.type==PERSON.find('Asghar Farhadi'):
        print("Found Person:", subj)  # Debugging statement

# %%
# Iterate through all triples in the graph
for subj, pred, obj in g:
    # Check if the predicate is of type RDF.type and the object is :Person
    if pred == RDF.type and obj == g.value("http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person"):
        print("Found Person:", subj)  # Print the subject

# %%
ns = Namespace("http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#")
xsd = Namespace("http://www.w3.org/2001/XMLSchema#")

# Find individuals of type Person
persons = set()
for subject, predicate, obj in g:
    if (subject, RDF.type, ns.Person) in g:
        persons.add(subject)

# Extract and print the names
for person in persons:
    # Find the name of the person
    name = g.value(person, ns.Name)
    if name:
        print(name)
print(person)
# Out:
# http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person

# %%
import pprint
for stmt in g:
    pprint.pprint(stmt)
# Out:
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Giuseppe_Tornatore'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Director'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#A_Separation'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Asghar_Farhadi'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Richard_Curtis'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Richard Curtis'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Miyu_Irino'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topDataProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Asghar_Farhadi'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Lucy_Liu'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Enzo_Cannavale'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('96', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Shahab_Hosseini'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Forrest Gump'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Laeta_Kalogridis'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Female'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Laeta_Kalogridis'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Uma_Thurman'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Domhnall_Gleeson'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('39', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kevin_Hart'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Crime'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Central Intelligence'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rachel_McAdams'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Vivica_A_Fox'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Domhnall_Gleeson'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Richard_Curtis'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'),
#  rdflib.term.Literal('English'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Leila_Hatami'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('49', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Family'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Robin_Wright'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Martin_Scorsese'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Animation'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Audrey_Tautou'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Thriller'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mathieu_Kassovitz'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('French'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Action'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Adventure'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Jean_Pierre_Jeunet'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('French'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mystery'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Miyu_Irino'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('Japanese'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Asghar_Farhadi'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('50', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Peyman_Moaadi'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gary_Sinise'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('66', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Guillaume_Laurant'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isWriterOf'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Winston_Groom'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#About_Time'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Richard_Curtis'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Cinema_Paradiso'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'),
#  rdflib.term.Literal('Italian'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Leonardo_DiCaprio'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Leonardo DiCaprio'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Domhnall_Gleeson'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Domhnall Gleeson'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Dwayne_Johnson'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Vivica_A_Fox'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Action'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Leonardo_DiCaprio'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mathieu_Kassovitz'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Shutter_Island'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Thriller'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rumi_Hiiragi'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('51', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isActorOf'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Leila_Hatami'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#inverseOf'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isGenreOf'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rufus'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Antonella_Attili'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Female'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'),
#  rdflib.term.Literal('English'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Country'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Shutter_Island'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ben_Kingsley'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Guillaume_Laurant'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Female'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Dwayne_Johnson'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Dwayne Johnson'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Sareh_Bayat'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('52', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Martin_Scorsese'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rufus'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Martin_Scorsese'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('79', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Tom_Hanks'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Audrey_Tautou'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mari_Natsuki'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#A_Separation'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Shutter_Island'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'),
#  rdflib.term.Literal('English'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Samuel_L_Jackson'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#FunctionalProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Cinema_Paradiso'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Antonella_Attili'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Samuel_L_Jackson'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isDirectorOf'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#David_Carradine'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('72', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Enzo_Cannavale'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Enzo Cannavale'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kevin_Hart'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rumi_Hiiragi'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Female'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mathieu_Kassovitz'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Ontology'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Jean_Pierre_Jeunet'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Shahab_Hosseini'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Shahab Hosseini'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Cinema_Paradiso'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'),
#  rdflib.term.Literal('1988-01-01T00:00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Asghar_Farhadi'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#David_Stassen'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('David Stassen'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Jean_Pierre_Jeunet'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Sareh_Bayat'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('Iranian'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Robin_Wright'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('55', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Crime'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rumi_Hiiragi'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('Japanese'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ben_Kingsley'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('British'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Lucy_Liu'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Lucy_Liu'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Lucy Liu'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#A_Separation'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Sareh_Bayat'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Martin_Scorsese'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Director'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Cinema_Paradiso'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Philippe_Noiret'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Tom_Hanks'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Female'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amy_Ryan'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Amy Ryan'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Samuel_L_Jackson'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Uma_Thurman'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Quentin_Tarantino'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'),
#  rdflib.term.Literal('Japanese'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isActorOf'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#John_Travolta'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Asghar_Farhadi'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Giuseppe_Tornatore'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Giuseppe Tornatore'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Bill_Nighy'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('72', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ike_Barinholtz'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Animation'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rachel_McAdams'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mark_Ruffalo'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Mark Ruffalo'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Enzo_Cannavale'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kevin_Hart'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Leila_Hatami'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Leila Hatami'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Robert_Zemeckis'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Audrey_Tautou'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amy_Ryan'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Eric_Roth'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Romantic'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isDirectorOf'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ike_Barinholtz'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Crime'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#About_Time'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Bill_Nighy'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Comedy'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mark_Ruffalo'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Laeta_Kalogridis'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('58', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Pulp_Fiction'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Quentin_Tarantino'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Thriller'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Giuseppe_Tornatore'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Laeta_Kalogridis'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Laeta Kalogridis'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#David_Carradine'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'),
#  rdflib.term.Literal('1994-01-01T00:00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#inverseOf'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isActorOf'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amy_Ryan'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#A_Separation'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Country'),
#  rdflib.term.Literal('Iran'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Sareh_Bayat'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'),
#  rdflib.term.Literal('French'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rawson_Marshall_Thurber'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mathieu_Kassovitz'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('54', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Tom_Hanks'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('65', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Robin_Wright'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Female'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Eric_Roth'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mari_Natsuki'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Jean_Pierre_Jeunet'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('68', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Quentin_Tarantino'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Director'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mari_Natsuki'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('74', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Antonella_Attili'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Quentin_Tarantino'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('59', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# ...
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ike_Barinholtz'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Ike Barinholtz'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#FunctionalProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Family'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Antonella_Attili'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('74', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Hayao_Miyazaki'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('81', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#David_Stassen'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Country'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rawson_Marshall_Thurber'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ben_Kingsley'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('78', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Giuseppe_Tornatore'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('Italian'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Guillaume_Laurant'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Bill_Nighy'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('British'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ben_Kingsley'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mystery'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Uma_Thurman'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Uma Thurman'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Lucy_Liu'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Country'),
#  rdflib.term.Literal('Japan'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ike_Barinholtz'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#About_Time'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rachel_McAdams'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Dwayne_Johnson'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Audrey_Tautou'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Audrey Tautou'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Cinema_Paradiso'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isWriterOf'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Peyman_Moaadi'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('Iranian'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#John_Travolta'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('John Travolta'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Miyu_Irino'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Audrey_Tautou'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('French'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'),
#  rdflib.term.Literal('2001-01-01T00:00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Spirited Away'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Pulp_Fiction'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#John_Travolta'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#David_Stassen'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('41', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Tom_Hanks'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#A_Separation'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'),
#  rdflib.term.Literal('2001-01-01T00:00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Vivica_A_Fox'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Miyu_Irino'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rawson_Marshall_Thurber'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Hayao_Miyazaki'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'),
#  rdflib.term.Literal('Hayao Miyazaki'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Laeta_Kalogridis'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gary_Sinise'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Bill_Nighy'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'),
#  rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Guillaume_Laurant'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('French'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kevin_Hart'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('42', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Philippe_Noiret'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Antonella_Attili'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('Italian'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Eric_Roth'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'),
#  rdflib.term.Literal('76', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Eric_Roth'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Robin_Wright'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'),
#  rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#About_Time'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))

# %%
# Iterate over triples in store and print them out.
print("--- printing raw triples ---")
for s, p, o in g:
    print((s, p, o))
# Out:
# --- printing raw triples ---
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Giuseppe_Tornatore'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Director'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#A_Separation'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Asghar_Farhadi'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Richard_Curtis'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Richard Curtis'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Miyu_Irino'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topDataProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Asghar_Farhadi'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Lucy_Liu'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Enzo_Cannavale'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('96', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Shahab_Hosseini'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Forrest Gump'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Laeta_Kalogridis'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Female'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Laeta_Kalogridis'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Uma_Thurman'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Domhnall_Gleeson'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('39', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kevin_Hart'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Crime'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Central Intelligence'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rachel_McAdams'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Vivica_A_Fox'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Domhnall_Gleeson'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Richard_Curtis'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'), rdflib.term.Literal('English'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Leila_Hatami'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('49', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Family'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Robin_Wright'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Martin_Scorsese'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Animation'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Audrey_Tautou'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Thriller'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mathieu_Kassovitz'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('French'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Action'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Adventure'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Jean_Pierre_Jeunet'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('French'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mystery'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Miyu_Irino'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('Japanese'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Asghar_Farhadi'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('50', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Peyman_Moaadi'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gary_Sinise'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('66', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Guillaume_Laurant'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isWriterOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Winston_Groom'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#About_Time'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Richard_Curtis'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Cinema_Paradiso'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'), rdflib.term.Literal('Italian'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Leonardo_DiCaprio'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Leonardo DiCaprio'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Domhnall_Gleeson'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Domhnall Gleeson'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Dwayne_Johnson'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Vivica_A_Fox'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Action'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Leonardo_DiCaprio'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mathieu_Kassovitz'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Shutter_Island'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Thriller'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rumi_Hiiragi'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('51', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isActorOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Leila_Hatami'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#inverseOf'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isGenreOf'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rufus'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Antonella_Attili'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Female'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'), rdflib.term.Literal('English'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Country'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Shutter_Island'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ben_Kingsley'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Guillaume_Laurant'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Female'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Dwayne_Johnson'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Dwayne Johnson'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Sareh_Bayat'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('52', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Martin_Scorsese'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rufus'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Martin_Scorsese'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('79', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Tom_Hanks'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Audrey_Tautou'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mari_Natsuki'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#A_Separation'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Shutter_Island'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'), rdflib.term.Literal('English'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Samuel_L_Jackson'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#FunctionalProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Cinema_Paradiso'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Antonella_Attili'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Samuel_L_Jackson'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isDirectorOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#David_Carradine'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('72', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Enzo_Cannavale'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Enzo Cannavale'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kevin_Hart'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rumi_Hiiragi'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Female'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mathieu_Kassovitz'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Ontology'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Jean_Pierre_Jeunet'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Shahab_Hosseini'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Shahab Hosseini'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Cinema_Paradiso'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'), rdflib.term.Literal('1988-01-01T00:00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Asghar_Farhadi'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#David_Stassen'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('David Stassen'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Jean_Pierre_Jeunet'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Sareh_Bayat'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('Iranian'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Robin_Wright'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('55', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Crime'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rumi_Hiiragi'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('Japanese'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ben_Kingsley'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('British'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Lucy_Liu'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Lucy_Liu'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Lucy Liu'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#A_Separation'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Sareh_Bayat'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Martin_Scorsese'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Director'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Cinema_Paradiso'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Philippe_Noiret'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Tom_Hanks'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Female'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amy_Ryan'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Amy Ryan'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Samuel_L_Jackson'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Uma_Thurman'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Quentin_Tarantino'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'), rdflib.term.Literal('Japanese'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isActorOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#John_Travolta'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Asghar_Farhadi'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Giuseppe_Tornatore'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Giuseppe Tornatore'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Bill_Nighy'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('72', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ike_Barinholtz'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Animation'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rachel_McAdams'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mark_Ruffalo'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Mark Ruffalo'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Enzo_Cannavale'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kevin_Hart'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Leila_Hatami'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Leila Hatami'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Robert_Zemeckis'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Audrey_Tautou'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amy_Ryan'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Eric_Roth'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Romantic'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isDirectorOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ike_Barinholtz'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Crime'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#About_Time'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Bill_Nighy'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Comedy'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mark_Ruffalo'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Laeta_Kalogridis'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('58', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Pulp_Fiction'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Quentin_Tarantino'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Thriller'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Giuseppe_Tornatore'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Laeta_Kalogridis'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Laeta Kalogridis'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#David_Carradine'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'), rdflib.term.Literal('1994-01-01T00:00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#inverseOf'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isActorOf'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amy_Ryan'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#A_Separation'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Country'), rdflib.term.Literal('Iran'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Sareh_Bayat'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Language'), rdflib.term.Literal('French'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rawson_Marshall_Thurber'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mathieu_Kassovitz'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('54', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Tom_Hanks'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('65', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Robin_Wright'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Female'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Eric_Roth'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mari_Natsuki'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Jean_Pierre_Jeunet'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('68', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Quentin_Tarantino'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Director'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mari_Natsuki'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('74', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Antonella_Attili'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Quentin_Tarantino'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('59', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ben_Kingsley'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# ...
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ike_Barinholtz'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Ike Barinholtz'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#FunctionalProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Family'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Antonella_Attili'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('74', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Hayao_Miyazaki'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('81', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#David_Stassen'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Country'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Genre'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rawson_Marshall_Thurber'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ben_Kingsley'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('78', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Giuseppe_Tornatore'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('Italian'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Guillaume_Laurant'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Bill_Nighy'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('British'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ben_Kingsley'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Mystery'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Uma_Thurman'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Uma Thurman'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Lucy_Liu'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Country'), rdflib.term.Literal('Japan'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Ike_Barinholtz'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#About_Time'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rachel_McAdams'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Dwayne_Johnson'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Audrey_Tautou'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Audrey Tautou'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Cinema_Paradiso'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#isWriterOf'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Writer'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Person'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Peyman_Moaadi'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('Iranian'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#topObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#John_Travolta'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('John Travolta'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Miyu_Irino'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Audrey_Tautou'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('French'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'), rdflib.term.Literal('2001-01-01T00:00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Spirited_Away'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Spirited Away'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Pulp_Fiction'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#John_Travolta'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#David_Stassen'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('41', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Tom_Hanks'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#A_Separation'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Amélie'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Year'), rdflib.term.Literal('2001-01-01T00:00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasGenre'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Drama'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kill_Bill_Volume_1'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasActor'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Vivica_A_Fox'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Miyu_Irino'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Central_Intelligence'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Rawson_Marshall_Thurber'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Hayao_Miyazaki'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Name'), rdflib.term.Literal('Hayao Miyazaki'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Laeta_Kalogridis'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#NamedIndividual'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gary_Sinise'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Bill_Nighy'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Gender'), rdflib.term.Literal('Male'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Guillaume_Laurant'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('French'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Kevin_Hart'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('42', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Philippe_Noiret'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Actor'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Antonella_Attili'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('Italian'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Eric_Roth'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Age'), rdflib.term.Literal('76', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Forrest_Gump'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasWriter'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Eric_Roth'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#hasDirector'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#ObjectProperty'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Robin_Wright'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Nationality'), rdflib.term.Literal('American'))
# (rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#About_Time'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.semanticweb.org/shaima/ontologies/2024/3/untitled-ontology-2#Movie'))

# %%
g.serialize(destination="tbl.ttl")
# Out:
# <Graph identifier=N2a4198fbd5484265acfc4ea0b06e7f04 (<class 'rdflib.graph.Graph'>)>

# %%
print(len(g))
# Out:
# 531

# %%
g = Graph()
g.parse("D:/Semester10/Ontologies/project/mm.ttl", format="ttl")

print(f"Graph has {len(g)} statements.")

def acctor():
    query1 = """
    SELECT ?actor WHERE {
    # ?actor a :Actor.
    }
    """

    # Execute the first query
    print("Movies and their genres:")
    for row in g.query(query1):
        # Extracting the local name from the URIs
        my_actor = row.actor.split('#')[-1]  # Split the URI by '#' and take the last part
        print(f"Actor: {my_actor}")

def writers():
    query3 = """
        SELECT ?writer WHERE {
        # ?writer a :Writer.
        }
        """
    print("Wrtiers of movies")
    for row in g.query(query3):
        my_writer = row.writer.split("#")[-1]
        print(f"Writer: {my_writer}")

def director():
    query="""
    SELECT ?director WHERE {
      # ?director a :Director.
    }
    """
    print("Directors of movies")
    for row in g.query(query):
        my_director = row.director.split("#")[-1]
        print(f"Director: {my_director}")

def ThrillerMoviesDirectors():
    query="""
    SELECT ?movie ?director WHERE {
      # ?movie a :Movie;
            :hasGenre :Thriller;
            :hasDirector ?director.
    }
    """
    print("Thriller Movies and Thier directors")
    for row in g.query(query):
        my_movie = row.movie.split("#")[-1]
        my_director = row.director.split("#")[-1]
        print(f"Movie: {my_movie}",f"Director: {my_director}")

def crime_thriller_movies():
    query = """
    SELECT ?movie WHERE {
      # ?movie a :Movie;
             :hasGenre :Crime, :Thriller.
    }
    """
    print("Crime and Thriller Movies:")
    for row in g.query(query):
        movie_name = row.movie.split('#')[-1]
        print(f"Movie: {movie_name}")

def male_actors_of_movie(movie_uri):    
    query = f"""
    SELECT ?actor WHERE {{
      :{movie_uri} a :Movie;
             :hasActor ?actor.
      # ?actor :Gender "Male".
    }}
      """  
    print(f"Male actors of the movie {movie_uri}:")
    for row in g.query(query):
        actor_name = row.actor.split('#')[-1] if '#' in row.actor else row.actor.split('/')[-1]
        print(f"Actor: {actor_name}")

def count_action_thriller_movies():
    # This query assumes that a movie can have multiple genres and counts movies that include both genres.
    query = """
    SELECT (COUNT(DISTINCT ?movie) as ?movieCount) WHERE {
      # ?movie a :Movie.
      # ?movie :hasGenre :Action.
      # ?movie :hasGenre :Thriller.
    }
    """
    result = g.query(query)
    # Access the count from the query results
    for row in result:
        # The count result can be accessed using row.movieCount in RDFlib
        print("Count of Action and Thriller Movies:", row.movieCount)

def movies_by_writer(writer_uri):
    query = f"""
    SELECT ?movie WHERE {{
      # ?movie a :Movie;
             :hasWriter :{writer_uri}.
    }}
    """
    print(f"Movies written by {writer_uri.split('#')[-1]}:")
    for row in g.query(query):
        movie_name = row.movie.split('#')[-1]
        print(f"Movie: {movie_name}")

def movies_by_language(language):
    query = f"""
    SELECT ?movie WHERE {{
      # ?movie a :Movie;
             :Language "{language}".
    }}
    """
    print(f"Movies in {language}:")
    for row in g.query(query):
        movie_name = row.movie.split('#')[-1]
        print(f"Movie: {movie_name}")

def actors_by_age(min_age):
    query = f"""
    SELECT ?actor WHERE {{
      # ?actor a :Actor;
             :Age ?age.
      FILTER(?age > {min_age})
    }}
    """
    print(f"Actors older than {min_age} years:")
    for row in g.query(query):
        actor_name = row.actor.split('#')[-1]
        print(f"Actor: {actor_name}")

def actors_and_their_movies():
    query = """
    SELECT ?actor ?movie WHERE {
      # ?movie a :Movie;
             :hasActor ?actor.
      # ?actor a :Actor.
    }
    """
    print("Actors and their movies:")
    for row in g.query(query):
        actor_name = row.actor.split('#')[-1]
        movie_name = row.movie.split('#')[-1]
        print(f"Actor: {actor_name}, Movie: {movie_name}")

def count_movies_by_directors():
    query = """
    SELECT ?director (COUNT(?movie) as ?numberOfMovies) WHERE {
      # ?movie a :Movie;
              :hasDirector ?director.
      # ?director a :Director;
    } GROUP BY ?director
    """
    print("Number of movies directed by each director:")
    for row in g.query(query):
        director_name = row.director.split('#')[-1]
        print(f"Director: {director_name}, Number of Movies: {row.numberOfMovies}")

def directors_who_act_and_direct():
    query = """
    SELECT ?movie ?director WHERE {
      # ?movie a :Movie;
              :hasDirector ?director.
      # ?director a :Director.
      # ?director a :Actor.
    }
    """
    print("Movies directed and acted in by the same director:")
    for row in g.query(query):
        director_name = row.director.split('#')[-1]
        movie_name = row.movie.split('#')[-1]
        print(f"Director: {director_name}, Movie: {movie_name}")

def directors_who_never_acted():
    query = """
    SELECT ?director WHERE {
      # ?director a :Director.
      FILTER NOT EXISTS {
        # ?movie :hasActor ?director.
      }
    }
    """
    print("Directors who have never acted in any movie:")
    for row in g.query(query):
        director_name = row.director.split('#')[-1]
        print(f"Director: {director_name}")

def actors_in_drama():
    query = """
    SELECT DISTINCT ?actor WHERE {
      # ?movie a :Movie;
            :hasActor ?actor.
      # ?actor a :Actor.
      # ?movie :hasGenre :Drama.
    }
    """
    print("Actors who have acted in Drama movies:")
    for row in g.query(query):
        actor_name = row.actor.split('#')[-1]  # Assuming URI ends with '#'
        print(f"Actor: {actor_name}")

def query_movies_with_optional_info():

    query = """
    SELECT ?movie ?director ?writer WHERE {
      # ?movie a :Movie.
      OPTIONAL {
        # ?movie :hasDirector ?director.
        # ?director a :Director.
      }
      OPTIONAL {
        # ?movie :hasWriter ?writer.
        # ?writer a :Writer.
      }
    }
    """
    print("Movies with their optional director and writer info:")
    for row in g.query(query):
        movie_name = row.movie.split('#')[-1] if '#' in row.movie else row.movie.split('/')[-1]
        director_name = row.director.split('#')[-1] if row.director is not None else "No director"
        writer_name = row.writer.split('#')[-1] if row.writer is not None else "No writer"
        print(f"Movie: {movie_name}, Director: {director_name}, Writer: {writer_name}")

def query_people_by_roles_and_genres():
    query = """
    SELECT ?person ?role ?genre WHERE {
      {
        # ?movie a :Movie;
                :hasDirected ?person.
        # ?person a :Director;
                :hasDirected ?movie.
        BIND("Director" AS ?role).
      } UNION {
        # ?movie a :Movie;
                :hasActor ?person.
        BIND("Writer" AS ?role).
      }
      # ?movie :hasGenre ?genre.
      FILTER(?genre IN (:Thriller, :Drama))
    }
    """
    print("People and their roles in Thriller or Drama movies:")
    for row in g.query(query):
        person_name = row.person.split('#')[-1] if '#' in row.person else row.person.split('/')[-1]
        role = row.role
        genre = row.genre.split('#')[-1] if '#' in row.genre else row.genre.split('/')[-1]
        print(f"Person: {person_name}, Role: {role}, Genre: {genre}")

def construct_roles_graph():
    query = """
    SELECT ?person ?movie ?role WHERE {
      {
        # ?movie :hasDirector ?person.
        # ?person a :Director.
        BIND("Director" AS ?role).
      } UNION {
        # ?movie :hasWriter ?person.
        # ?person a :Writer.
        BIND("Writer" AS ?role).
      } UNION {
        # ?movie :hasActor ?person.
        # ?person a :Actor.
        BIND("Actor" AS ?role).
      }
    }
    """
    # Execute the query
    print("People and their roles in movies:")
    for row in g.query(query):
        person_name = row.person.split('#')[-1] if '#' in row.person else row.person.split('/')[-1]
        movie_name = row.movie.split('#')[-1] if '#' in row.movie else row.movie.split('/')[-1]
        role = row.role
        print(f"Person: {person_name}, Movie: {movie_name}, Role: {role}")

def check_for_thriller_with_female_director():
    query = """
    ASK {
      # ?movie a :Movie;
             :hasGenre :Thriller;
             :hasDirector ?director.
      # ?director a :Director;
                :gender :Female.
    }
    """
    # Execute the ASK query
    result = g.query(query)
    
    # Result is a boolean, so we check if it's True or False
    if result:
        print("Yes, there is at least one thriller movie directed by a female director.")
    else:
        print("No, there are no thriller movies directed by a female director.")

def describe_movie(title):
    # Properly formatted SPARQL query with title as a string literal
    query = f"""
    DESCRIBE ?movie
    WHERE {{
      # ?movie a :Movie;
             :Name "{title}".
    }}
    """
    # Execute the DESCRIBE query
    described_graph = g.query(query).graph
    
    # Output the results, extracting local names after '#'
    print(f"Description of the movie '{title}':")
    for s, p, o in described_graph:
        subject_local = s.split('#')[-1] if '#' in str(s) else str(s)
        predicate_local = p.split('#')[-1] if '#' in str(p) else str(p)
        object_local = o.split('#')[-1] if isinstance(o, URIRef) and '#' in str(o) else str(o)
        print(f"Subject: {subject_local}, Predicate: {predicate_local}, Object: {object_local}")

def list_movies_with_multiple_genres(g):
    query = """
    SELECT ?movie (COUNT(?genre) AS ?genresCount) WHERE {
      # ?movie a :Movie;
             :hasGenre ?genre.
    } GROUP BY ?movie
      HAVING(COUNT(?genre) >= 3)
    """
    # Execute the query
    results = g.query(query)
    
    # Output the results
    print("Movies with at least three different genres:")
    for row in results:
        movie_uri = row.movie
        movie_name = movie_uri.split('#')[-1] if '#' in str(movie_uri) else str(movie_uri)
        genres_count = row.genresCount
        print(f"Movie: {movie_name}, Genres Count: {genres_count}")

def list_movies_by_director_actors(g):
    query = """
    SELECT DISTINCT ?movie WHERE {
      # ?movie a :Movie;
             :hasDirector ?director.
      # ?director a :Director.
      # ?director a :Actor.
    }
    """
    # Execute the query
    try:
        results = g.query(query)
        # Output the results
        print("Movies directed by directors who also acted in movies:")
        for row in results:
            movie_uri = row.movie
            movie_name = movie_uri.split('#')[-1] if '#' in str(movie_uri) else str(movie_uri)
            print(f"Movie: {movie_name}")
    except Exception as e:
        print(f"An error occurred: {e}")

def find_actors_in_multiple_genres(g):
    query = """
    SELECT ?actor ?movie ?genre WHERE {
      # ?movie a :Movie;
              :hasActor ?actor.
      # ?actor a :Actor;
             :Age ?age.
      # ?movie :hasGenre ?genre.
      FILTER(?age > 50)
    }
    """
    # Execute the query
    results = g.query(query)
    
    # Process the results to count distinct genres per actor
    from collections import defaultdict
    actor_genres = defaultdict(set)  # Use a set to keep genres unique
    
    for row in results:
        actor_uri = row.actor
        genre = row.genre
        actor_genres[actor_uri].add(genre)

    # Output actors who have acted in at least two different genres
    print("Actors over 50 who have acted in at least two different genres:")
    for actor, genres in actor_genres.items():
        if len(genres) >= 2:
            actor_name = actor.split('#')[-1] if '#' in str(actor) else str(actor)
            print(f"Actor: {actor_name}, Genres Count: {len(genres)}")


def list_movies_with_triple_roles(g):
    query = """
    SELECT ?movie WHERE {
      # ?movie a :Movie;
             :hasActor ?person;
             :hasDirector ?person;
             :hasWriter ?person.
      # ?person a :Person.
    }
    """
    # Execute the query
    results = g.query(query)
    
    # Output the results
    print("Movies where the same person is an actor, director, and writer:")
    for row in results:
        movie_uri = row.movie
        movie_name = movie_uri.split('#')[-1] if '#' in str(movie_uri) else str(movie_uri)
        print(f"Movie: {movie_name}")

def list_directors_with_no_thriller_movies(g):
    query = """
    SELECT DISTINCT ?director WHERE {
      # ?director a :Director.
      FILTER NOT EXISTS {
        # ?movie a :Movie;
                :hasDirector ?director;
                :hasGenre :Thriller.
      }
    }
    """
    # Execute the query
    results = g.query(query)
    
    # Output the results
    print("Directors who have never directed a Thriller movie:")
    for row in results:
        director_uri = row.director
        director_name = director_uri.split('#')[-1] if '#' in str(director_uri) else str(director_uri)
        print(f"Director: {director_name}")
# Out:
# Graph has 525 statements.
